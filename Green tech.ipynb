# %%
import pandas as pd
df=pd.read_csv('green_tech_data.csv')
df.head(3)
# Out:
#    carbon_emissions  energy_output  renewability_index  cost_efficiency  \
# 0        181.089042     128.286267            0.642032         0.732568
# 1        382.750007     672.769370            0.084140         2.891096
# 2        306.197880     382.920383            0.161629         2.932858
#
#    sustainability
# 0               1
# 1               0
# 2               0

# %%
df.columns
# Out:
# Index(['carbon_emissions', 'energy_output', 'renewability_index',
#        'cost_efficiency', 'sustainability'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# carbon_emissions      0
# energy_output         0
# renewability_index    0
# cost_efficiency       0
# sustainability        0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# carbon_emissions      float64
# energy_output         float64
# renewability_index    float64
# cost_efficiency       float64
# sustainability          int64
# dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.columns
# Out:
# Index(['carbon_emissions', 'energy_output', 'renewability_index',
#        'cost_efficiency', 'sustainability'],
#       dtype='object')

# %%
x = df[['carbon_emissions', 'energy_output', 'renewability_index',
       'cost_efficiency']]
y = df['sustainability']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# y_pred = model.predict(X_test)

# %%
y_pred = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)*100

# %%
print("Confusion Matrix:\n", cm)
print("\nAccuracy Score:", accuracy)
# Out:
# Confusion Matrix:
#  [[17  0]
#  [ 1  2]]
#
# Accuracy Score: 95.0

# %%
conf_matrix  = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Sustainable', 'Sustainable'],
            yticklabels=['Not Sustainable', 'Sustainable'])
plt.xlabels('Predicted')
plt.ylabels('Actual')
plt.title('Confusion Matrix')
plkt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 5
#       1 conf_matrix  = confusion_matrix(y_test, y_pred)
#       2 sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
#       3             xticklabels=['Not Sustainable', 'Sustainable'],
#       4             yticklabels=['Not Sustainable', 'Sustainable'])
# ----> 5 plt.xlabels('Predicted')
#       6 plt.ylabels('Actual')
#       7 plt.title('Confusion Matrix')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlabels'

# %%
import pickle
#save the model to a file
with open ('lrmodel_sustainabel.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\susha\\OneDrive\\Documents\\Desktop\\Deploy'
